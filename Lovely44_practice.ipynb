# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely44_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "Python" .strip() .upper()
print("Python".strip().upper())
# Out:
# PYTHON

# %%
#use lower() .strip()
print("Python".strip().lower())
# Out:
# python

# %%
#Ask user for name and print strip().title()
name = input("enter your name:")
print(name)
# Out:
# enter your name:Lovely
# Lovely

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "pineapple"
print(fruit)
# Out:
# pineapple

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Black
# Black

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: replace()
text = "I love Python"
print(text.replace("Python", "Java"))
# Out:
# I love Java

# %%
#Revision: startswith()
name = "lovely"
print(name.startswith("lo"))
# Out:
# True

# %%
#Print "Day 44 complete!"
print("Day 44 complete!")
# Out:
# Day 44 complete!

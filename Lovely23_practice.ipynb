# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely23_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check if "python" .startswith ("py")
word = "python"
print(word.startswith("py"))
# Out:
# True

# %%
#check if "lovely" .startswith ("lo")
name = "lovely"
print(name.startswith("lo"))
# Out:
# True

# %%
#ask user for test and check .startswith ("A")
text = input("enter a text:")
print(text.startswith("A"))
# Out:
# enter a text:Apple
# True

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#creat a fruit variable and print it
fruit = "Apple"
print(fruit)
# Out:
# Apple

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Yellow
# Yellow

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print"day 23 complete!"
print("Day 23 complete!")
# Out:
# Day 23 complete!

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely19_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
first = "Hi"
second = "Lovely"
print (first+" "+second)
# Out:
# Hi Lovely

# %%
city = "Ranchi"
country = "India"
print (city+","+country)
# Out:
# Ranchi,India

# %%
name = input("enter your name:")
print ("Hello"" "+name)
# Out:
# enter your name:Lovely
# Hello Lovely

# %%
food = "mango"
print ("I like"" "+ food)
# Out:
# I like mango

# %%
for i in range (1,4):
    print (i)
# Out:
# 1
# 2
# 3

# %%
print ("Python"" "+"Rocks")
# Out:
# Python Rocks

# %%
print ("Awesome!")
# Out:
# Awesome!

# %%
print (len("cat"))
# Out:
# 3

# %%
print ("Day 19 complete ❤️")
# Out:
# Day 19 complete ❤️

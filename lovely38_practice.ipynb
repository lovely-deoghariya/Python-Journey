# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/lovely38_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a,b = 1,2: print(a,b)
a,b = 1,2
print(a,b)
# Out:
# 1 2

# %%
#name, age = "lovely", 20
name,age = "lovely", 20
print(name, age)
# Out:
# lovely 20

# %%
#x,h = "tea", "cake"
x,y = "tea", "cake"
print(x,y)
# Out:
# tea cake

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#fruit variable
fruit = "mango"
print(fruit)
# Out:
# mango

# %%
#favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:White
# White

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: input()
name = input("enter your name:")
print(name)
# Out:
# enter your name:Lovely
# Lovely

# %%
#Revision: strip()
name = " vishal "
print(name.strip())
# Out:
# vishal

# %%
#print "Day 38 complete!"
print("Day 38 complete!")
# Out:
# Day 38 complete!

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely20_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "lovely"
print (name.upper())
# Out:
# LOVELY

# %%
name = "Lovely"
print (len(name))
# Out:
# 6

# %%
print ("Good"" "+"Morning")
# Out:
# Good Morning

# %%
print (not False)
# Out:
# True

# %%
print (5>2 and 8>4)
# Out:
# True

# %%
print (5>9 or 2<4)
# Out:
# True

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
food = input("enter your favourite food:")
print (food)
# Out:
# enter your favourite food:Laddu
# Laddu

# %%
print ("I love you Vishal❤️😚")
# Out:
# I love you Vishal❤️😚

# %%
print ("Day 20

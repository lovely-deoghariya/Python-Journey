# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely48_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "Hi" .ljust(10)
print("Hi".ljust(10))
# Out:
# Hi

# %%
#print "Hi" .ljust(10)
print("Hi".ljust(10))
# Out:
# Hi

# %%
#ask user for a word and use .ijust()
word = input("enter a word:")
print(word.ljust(10))
# Out:
# enter a word:Python
# Python

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Yellow
# Yellow

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: strip()
name = "lovely"
print(name.strip())
# Out:
# lovely

# %%
#Revision: len()
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#print "Day 48 complete!"
print("Day 48 complete!")
# Out:
# Day 48 complete!

# %%
print ("Name = lovely")
print ("Favourite colour= pink")
# Out:
# Name = lovely
# Favourite colour= pink

# %%
name = "lovely"
age = "21"
city = "gumla"
print (name)
print (age)
print (city)
# Out:
# lovely
# 21
# gumla

# %%
number1 = int(input("enter your first number"))
number2 = int(input("enter your second number"))
print ("sum",number1+number2)
# Out:
# enter your first number20
# enter your second number10
# sum 30

# %%
print (10==10)
# Out:
# True

# %%
print (10!=5)
# Out:
# True

# %%
#create marks=80 use if else to print pass if marks>=35 otherwise fail
marks = 80
if marks >= 35:
    print ("pass")
else:
    print ("fail")
# Out:
# pass

# %%
#ask the user for their age print adult if age >=18 otherwise minor
age = int(input("enter your age"))
if age >=18:
    print ("adult")
else:
    print ("minor")

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range (5):
    print ("🧿😚")
# Out:
# 🧿😚
# 🧿😚
# 🧿😚
# 🧿😚
# 🧿😚

# %%
print ("see you tomorrow for day 6!❤️")
# Out:
# see you tomorrow for day 6!❤️

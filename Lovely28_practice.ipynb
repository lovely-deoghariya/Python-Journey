# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely28_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check "a" in "cat"
print("a" in "cat")
# Out:
# True

# %%
#check "z" in "python"
print("z" in "python")
# Out:
# False

# %%
#ask user for a word and check if "e" in it
word = input(" enter a word:")
print("e" in word)
# Out:
#  enter a word:Apple
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "Orange"
print(fruit)
# Out:
# Orange

# %%
#ask favourite colour
colour = input(" enter your favourite colour:")
print(colour)
# Out:
#  enter your favourite colour:Black
# Black

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 28 complete!"
print("Day 28 co

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely24_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#check if "photo.jpg" .endswith(".jpg")
filename = "photo.jpg"
print(filename.endswith(".jpg"))
# Out:
# True

# %%
#check if "python" .endswith("on")
word = "python"
print(word.endswith("on"))
# Out:
# True

# %%
#ask user for filename and check .endswith(".txt")
filename = input("enter a filename:")
print(filename.endswith(".txt"))
# Out:
# enter a filename:Notes.txt
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "watermelon"
print(fruit)
# Out:
# watermelon

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Green
# Green

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 24 complete!"
print("Day 24 complete!")
# Out:
# Day 24 complete!

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely41_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "good morning".title()
print("good morning".title())
# Out:
# Good Morning

# %%
#convert "python programming" to title case
print("python programming".title())
# Out:
# Python Programming

# %%
#ask user for name and print title()
name = input("enter your name:")
print(name.title())
# Out:
# enter your name:Lovely deoghariya
# Lovely Deoghariya

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "watermelon"
print(fruit)
# Out:
# watermelon

# %%
#Ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Green
# Green

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: upper()
name = input("enter your name:")
print(name.upper())
# Out:
# enter your name:Lovely
# LOVELY

# %%
#Revision: lower()
name = input("enter your name:")
print(name.lower())
# Out:
# enter your name:Lovely
# lovely

# %%
#print "day 41 complete!"
print("Day 41 complete!")
# Out:
# Day 41 complete!

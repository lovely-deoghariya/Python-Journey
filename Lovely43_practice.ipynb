# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely43_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "PYTHON" casefold()
print("PYTHON".casefold())
# Out:
# python

# %%
#compare "Python" and "python" using casefold()
print("Python".casefold() == "python".casefold())
# Out:
# True

# %%
#ask user for text and print casefold()
text = input("Enter text: ")
print(text.casefold())
# Out:
# Enter text: PyThOn
# python

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "mango"
print(fruit)
# Out:
# mango

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Pink
# Pink

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: isalpha()
name = input("enter your name:")
print(name.isalpha())
# Out:
# enter your name:Lovely123
# False

# %%
#Revision: strip()
name = "lovely"
print(name.strip())
# Out:
# lovely

# %%
#print "Day 43 complete!"
print("Day 43 complete!")
# Out:
# Day 43 complete!

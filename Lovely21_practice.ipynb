# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely21_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create name = "Lovely" and print name.strip()
name = " lovely "
print(name.strip())
# Out:
# lovely

# %%
#ask user for a name and use.strip()
name = input("enter your name:")
print(name.strip())
# Out:
# enter your name:Lovely
# Lovely

# %%
#print "Hi" .strip()
print("Hi".strip())
# Out:
# Hi

# %%
#print number 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "mango"
print (fruit)
# Out:
# mango

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Blue
# Blue

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 21 complete!"
print("Day 21 complete!")

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely10_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Lovely")
# Out:
# Lovely

# %%
#create age = 20 and print age <=20
age = 20
print (age

# %%
print (5<=2)
# Out:
# False

# %%
#use if else marks = 30 pass if marks <=35 print need improvement else good
marks = 30
if marks <=35 :
    print ("need improvement")
else:
    print ("Good")
# Out:
# need improvement

# %%
for i in range (2):
    print ("python")
# Out:
# python
# python

# %%
#create city variable and print it
city = "gumla"
print (city)
# Out:
# gumla

# %%
#Ask the user for their favourite fruit
fruit = input("enter your favourite fruit: ")
print (fruit)
# Out:
# enter your favourite fruit: Lichi
# Lichi

# %%
print (10<=10)
# Out:
# True

# %%
print ("Day 11 complete❤️")
# Out:
# Day 11 complete❤️

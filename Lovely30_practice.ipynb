# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely30_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create one program using input()
name = input("enter your name:")
print("Hello",name)
# Out:
# enter your name:Lovely
# Hello Lovely

# %%
#use upper() or lower()
name = input("enter your name:")
print(name.upper())
print(name.lower())
# Out:
# enter your name:Lovely
# LOVELY
# lovely

# %%
#use len() in same program
name = input("enter your name:")
print(name.upper())
print(len(name))
# Out:
# enter your name:Lovely
# LOVELY
# 6

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "Mango"
print(fruit)
# Out:
# Mango

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Green
# Green

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print "day 30 complete!"
print("Day 30 complete!")
# Out:
# Day 30 complete!

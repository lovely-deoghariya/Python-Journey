# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely18_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "lovely"
print (name.upper())
# Out:
# LOVELY

# %%
city = "DELHI"
print (city.lower())
# Out:
# delhi

# %%
name = input("enter your name:")
print (name.upper())
# Out:
# enter your name:vishal
# VISHAL

# %%
print ("python".upper())
# Out:
# PYTHON

# %%
for i in range (1,5):
    print (i)
# Out:
# 1
# 2
# 3
# 4

# %%
pet = "Dog"
print (pet)
# Out:
# Dog

# %%
print ("HELLO".lower())
# Out:
# hello

# %%
print ("keep learning ")
# Out:
# keep learning

# %%
fruit = input("enter your favourite fruit:")
print (fruit)
# Out:
# enter your favourite fruit:Lichi
# Lichi

# %%
print ("Day 18 complete❤️")
# Out:
# Day 18 complete❤️

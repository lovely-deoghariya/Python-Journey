# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely29_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print your name .upper()
name = "lovely"
print(name.upper())
# Out:
# LOVELY

# %%
#print len("python")
print(len("python"))
# Out:
# 6

# %%
#join "Good" + "Lucky"
first = "Good"
second = "Luck"
print(first+" "+second)
# Out:
# Good Luck

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable and print it
fruit = "grapes"
print(fruit)
# Out:
# grapes

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Purple
# Purple

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: print not False
print(not False)
# Out:
# True

# %%
#Revision: 5>2 and 7>3
print(5>2 and 7>3)
# Out:
# True

# %%
#print

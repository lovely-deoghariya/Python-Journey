# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely35_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ask user for name
name = input("enter your name:")
print(name)
# Out:
# enter your name:Lovely
# Lovely

# %%
#use strip()
name = input("enter your name:")
print(name.strip())
# Out:
# enter your name:Vishal
# Vishal

# %%
#use upper()
name = input("enter your name:")
print(name.upper())
# Out:
# enter your name:Vishal
# VISHAL

# %%
#print len(name)
name = input("enter your name:")
print(len(name))
# Out:
# enter your name:Vishal
# 6

# %%
#check .startswith("A")
name = input("enter your name:")
print(name.startswith("A"))
# Out:
# enter your name:Anshika
# True

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "watermelon"
print(fruit)
# Out:
# watermelon

# %%
#Revision: count("a")
word = input("enter a word:")
print(word.count("a"))
# Out:
# enter a word:Banana
# 3

# %%
#Revision: isalpha()
text = input("enter text:")
print(text.isalpha())
# Out:
# enter text:Vishal
# True

# %%
#print "day 35 complete!"
print("Day 35 complete!")
# Out:
# Day 35 complete!

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely16_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (not True)
# Out:
# False

# %%
print (not False)
# Out:
# True

# %%
print (not(5>2))
# Out:
# False

# %%
age = 16
if not (age >=18) :
    print ("minor")
# Out:
# minor

# %%
for i in range (1,4):
    print (i)
# Out:
# 1
# 2
# 3

# %%
city = input("enter your city")
print (city)
# Out:
# enter your cityGumla
# Gumla

# %%
#create food variable and print it
food = " biryani"
print (food)
# Out:
#  biryani

# %%
print (not(10>20))
# Out:
# True

# %%
print ("keep smiling")
# Out:
# keep smiling

# %%
print ("Day 16 complete!")
# Out:
# Day 16 complete!

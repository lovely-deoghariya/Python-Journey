# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely37_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "Hello\nlovely"
print("Hello\nlovely")
# Out:
# Hello
# lovely

# %%
#print "Hi\tlovely"
print("Hi\tlovely")
# Out:
# Hi	lovely

# %%
#print "I\"m learning python"
print("I\"m learning python")
# Out:
# I"m learning python

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#fruit variable
fruit = "Mango"
print(fruit)
# Out:
# Mango

# %%
#favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Green
# Green

# %%
#Print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: upper()
name = "lovely"
print(name.upper())
# Out:
# LOVELY

# %%
#Revision: len()
name = "vishal"
print(len(name))
# Out:
# 6

# %%
#print " day 37 complete!"
print("Day 37 complete!")
# Out:
# Day 37 complete!

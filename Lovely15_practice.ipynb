# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely15_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("lovely")
# Out:
# lovely

# %%
age = 18
print (age>=18)
# Out:
# True

# %%
marks = 80
print ( marks>=75)
# Out:
# True

# %%
marks = 75
if marks >=90:
    print ("Grade A")
elif marks>=75:
    print ("Grade B")
else:
    print ("Grade C")
# Out:
# Grade B

# %%
for i in range (1,6):
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
print (5!=4)
# Out:
# True

# %%
print (5<=5)
# Out:
# True

# %%
print (True or False)
# Out:
# True

# %%
print (False or True)
# Out:
# True

# %%
#celebrate day 15 by printing I can learn python!
print ("I can learn python

# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely14_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (True or False)
# Out:
# True

# %%
print (5>8 and 8>3)
# Out:
# False

# %%
#use if marks >= 90 or sports== yes
marks = 95
sports = "yes"
if marks >=90 or sports == "yes":
    print ( "eligible")
# Out:
# eligible

# %%
#create a pet variable
pet = "Dog"
print (pet)
# Out:
# Dog

# %%
for i in range (2,6):
    print (i)
# Out:
# 2
# 3
# 4
# 5

# %%
#ask favourite colour
colour = input("enter your favourite colour")
print (colour)
# Out:
# enter your favourite colourBlack
# Black

# %%
print (7<2 and 3<5)
# Out:
# False

# %%
print ("awesome")
# Out:
# awesome

# %%
#create score variable
score = 60
print (score)
# Out:
# 60

# %%
print ("Day 14 complete ❤️")
# Out:
# Day 14 complete ❤️

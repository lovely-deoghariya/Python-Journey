# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/python-journey/blob/main/Lovely09_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("biryani")
# Out:
# biryani

# %%
fruit = "apple"
price = "100"
city = "gumla"
print (fruit)
print (price)
print (city)
# Out:
# apple
# 100
# gumla

# %%
print (8!=5)
# Out:
# True

# %%
print (10!=10)
# Out:
# False

# %%
#create age = 18 use if else to print adult if age!=17 otherwise print seventeen
age = 18
if age !=17 :
    print ("adult")
else:
    print ("seventeen")
# Out:
# adult

# %%
#create colour= red print different if colour!= blue Otherwise print same
colour = "red"
if colour!= "blue":
    print ("different")
else:
    print ("same")
# Out:
# different

# %%
for i in range (5,0,-1):
    print (i)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
for i in range (4):
    print ("python is fun")
# Out:
# python is fun
# python is fun
# python is fun
# python is fun

# %%
print ("see you tomorrow for day 10!❤️")
# Out:
# see you tomorrow for day 10!❤️

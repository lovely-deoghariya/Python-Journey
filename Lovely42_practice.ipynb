# %% [markdown]
# <a href="https://colab.research.google.com/github/lovely-deoghariya/Python-Journey/blob/main/Lovely42_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#print "python" . capitalize()
print("python".capitalize())
# Out:
# Python

# %%
#capitalize "good morning"
print("good morning".capitalize())
# Out:
# Good morning

# %%
#ask user for name and print title()
sentence = input("enter a sentence:")
print(sentence.capitalize())
# Out:
# enter a sentence:good morning betuuu
# Good morning betuuu

# %%
#print 1 to 5
for i in range (1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#create a fruit variable
fruit = "lichi"
print(fruit)
# Out:
# lichi

# %%
#ask favourite colour
colour = input("enter your favourite colour:")
print(colour)
# Out:
# enter your favourite colour:Blue
# Blue

# %%
#print "keep learning!"
print("keep learning!")
# Out:
# keep learning!

# %%
#Revision: title()
name = "lovely"
print(name.title())
# Out:
# Lovely

# %%
#Revision: len()
name = "lovely"
print(len(name))
# Out:
# 6

# %%
#print "Day 42 complete!"
print("Day 42 complete!")
# Out:
# Day 42 complete!
